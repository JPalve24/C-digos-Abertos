# %%
# Criar dataframe
import pandas as pd
import numpy as np

# %%
series = pd.Series([7, 3, 2, np.nan, 6, 9]) # Séries temporais

# %%
series
# Out:
# 0    7.0
# 1    3.0
# 2    2.0
# 3    NaN
# 4    6.0
# 5    9.0
# dtype: float64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
datas = pd.date_range("20180101", periods=6)
# criar datas pd.date_range("periodo_inic", "periodo_fin", periodo = valor, freq = M, D, Y ...)

# %%
datas
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Data frame com valores aleatórios
df = pd.DataFrame(np.random.randn(6, 4), index = datas, columns= list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2018-01-01  0.354530 -0.355573  0.002859 -0.561262
# 2018-01-02  0.368262  2.686389  1.664944 -0.046484
# 2018-01-03 -1.528590  0.964888  0.688408  0.675600
# 2018-01-04  1.319901 -0.494623  1.671441  0.682866
# 2018-01-05 -0.574915 -1.362932 -1.015900 -0.408953
# 2018-01-06  0.819256 -0.812918 -0.370133 -0.850489

# %%
# Data frame criado com funções

df2 = pd.DataFrame({"A": 7, 
                    "B": pd.Timestamp("20190101"),
                    "C": pd.Series(1, index = list(range(4)), dtype = "float32"),
                    "D": np.array([3]*4, dtype= "int32"),
                    "E": pd.Categorical(["test", "train", "test", "train"]),
                    "F": "python"})

# %%
df2
# Out:
#    A          B    C  D      E       F
# 0  7 2019-01-01  1.0  3   test  python
# 1  7 2019-01-01  1.0  3  train  python
# 2  7 2019-01-01  1.0  3   test  python
# 3  7 2019-01-01  1.0  3  train  python

# %%
df2.dtypes # Retorna os tipos de dados de cada coluna
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
# Adicionar colunas

dat = pd.date_range("20220101", periods= 600, freq="D")
df = pd.DataFrame(np.random.randn(600, 5), index = dat, columns=list("ABCDE"))

# %%
df
# Out:
#                    A         B         C         D         E
# 2022-01-01 -1.500317 -1.147539  0.876408 -0.838264 -0.005721
# 2022-01-02  0.779477  0.665830  0.577448 -2.049250 -0.281789
# 2022-01-03 -0.078232  0.222300  0.060706  0.847890 -0.933266
# 2022-01-04  0.865010 -1.661046  0.817054 -0.736975 -1.371363
# 2022-01-05 -1.413822  0.463694  1.050720  2.080809  1.756232
# ...              ...       ...       ...       ...       ...
# 2023-08-19 -0.352227  0.702566  0.856665  0.775658 -1.380068
# 2023-08-20  0.401971 -0.082793 -0.717876 -0.762517 -1.561739
# 2023-08-21 -0.804089  1.457291  0.550251 -0.674637  0.417003
# 2023-08-22  0.094336 -0.498556 -0.754837 -2.052597 -0.255910
# 2023-08-23  0.403162 -1.343354  1.248397 -0.808786  1.376511
#
# [600 rows x 5 columns]

# %%
df.shape # linhas e colunas
# Out:
# (600, 5)

# %%
df.head(3)
# Out:
#                    A         B         C         D         E
# 2022-01-01 -1.500317 -1.147539  0.876408 -0.838264 -0.005721
# 2022-01-02  0.779477  0.665830  0.577448 -2.049250 -0.281789
# 2022-01-03 -0.078232  0.222300  0.060706  0.847890 -0.933266

# %%
df["F"] = 1

# %%
df.head(3)
# Out:
#                    A         B         C         D         E  F
# 2022-01-01 -1.500317 -1.147539  0.876408 -0.838264 -0.005721  1
# 2022-01-02  0.779477  0.665830  0.577448 -2.049250 -0.281789  1
# 2022-01-03 -0.078232  0.222300  0.060706  0.847890 -0.933266  1

# %%
df["G"] = range(600)

# %%
df.head(10)
# Out:
#                    A         B         C         D         E  F  G
# 2022-01-01 -1.500317 -1.147539  0.876408 -0.838264 -0.005721  1  0
# 2022-01-02  0.779477  0.665830  0.577448 -2.049250 -0.281789  1  1
# 2022-01-03 -0.078232  0.222300  0.060706  0.847890 -0.933266  1  2
# 2022-01-04  0.865010 -1.661046  0.817054 -0.736975 -1.371363  1  3
# 2022-01-05 -1.413822  0.463694  1.050720  2.080809  1.756232  1  4
# 2022-01-06  0.332259  0.182653  0.678313 -1.587172 -1.670557  1  5
# 2022-01-07  1.861717  0.524315 -1.020226  1.748898  2.559998  1  6
# 2022-01-08 -1.011126  0.252798 -0.422521 -0.759203  0.346843  1  7
# 2022-01-09  0.635914  0.204286  1.150767 -1.883346  0.152022  1  8
# 2022-01-10  0.162249  0.288972 -0.581700 -0.040008 -0.115849  1  9

# %%
# Produto de colunas

df["Produto"] = df["A"] * df["B"]
df
# Out:
#                    A         B         C         D         E  F    G   Produto
# 2022-01-01 -1.500317 -1.147539  0.876408 -0.838264 -0.005721  1    0  1.721672
# 2022-01-02  0.779477  0.665830  0.577448 -2.049250 -0.281789  1    1  0.518999
# 2022-01-03 -0.078232  0.222300  0.060706  0.847890 -0.933266  1    2 -0.017391
# 2022-01-04  0.865010 -1.661046  0.817054 -0.736975 -1.371363  1    3 -1.436822
# 2022-01-05 -1.413822  0.463694  1.050720  2.080809  1.756232  1    4 -0.655580
# ...              ...       ...       ...       ...       ... ..  ...       ...
# 2023-08-19 -0.352227  0.702566  0.856665  0.775658 -1.380068  1  595 -0.247463
# 2023-08-20  0.401971 -0.082793 -0.717876 -0.762517 -1.561739  1  596 -0.033281
# 2023-08-21 -0.804089  1.457291  0.550251 -0.674637  0.417003  1  597 -1.171792
# 2023-08-22  0.094336 -0.498556 -0.754837 -2.052597 -0.255910  1  598 -0.047032
# 2023-08-23  0.403162 -1.343354  1.248397 -0.808786  1.376511  1  599 -0.541589
#
# [600 rows x 8 columns]

# %%
# Substituir valores na coluna

df["D"] = 88
df
# Out:
#                    A         B         C   D         E  F    G   Produto
# 2022-01-01 -1.500317 -1.147539  0.876408  88 -0.005721  1    0  1.721672
# 2022-01-02  0.779477  0.665830  0.577448  88 -0.281789  1    1  0.518999
# 2022-01-03 -0.078232  0.222300  0.060706  88 -0.933266  1    2 -0.017391
# 2022-01-04  0.865010 -1.661046  0.817054  88 -1.371363  1    3 -1.436822
# 2022-01-05 -1.413822  0.463694  1.050720  88  1.756232  1    4 -0.655580
# ...              ...       ...       ...  ..       ... ..  ...       ...
# 2023-08-19 -0.352227  0.702566  0.856665  88 -1.380068  1  595 -0.247463
# 2023-08-20  0.401971 -0.082793 -0.717876  88 -1.561739  1  596 -0.033281
# 2023-08-21 -0.804089  1.457291  0.550251  88  0.417003  1  597 -1.171792
# 2023-08-22  0.094336 -0.498556 -0.754837  88 -0.255910  1  598 -0.047032
# 2023-08-23  0.403162 -1.343354  1.248397  88  1.376511  1  599 -0.541589
#
# [600 rows x 8 columns]

# %%
# Visualizar data frames

df.head(2) # 2 primeiras
# Out:
#                    A         B         C   D         E  F  G   Produto
# 2022-01-01 -1.500317 -1.147539  0.876408  88 -0.005721  1  0  1.721672
# 2022-01-02  0.779477  0.665830  0.577448  88 -0.281789  1  1  0.518999

# %%
df.tail(2) # 2 ultimas
# Out:
#                    A         B         C   D         E  F    G   Produto
# 2023-08-22  0.094336 -0.498556 -0.754837  88 -0.255910  1  598 -0.047032
# 2023-08-23  0.403162 -1.343354  1.248397  88  1.376511  1  599 -0.541589

# %%
df.index # valores do Indice
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10',
#                ...
#                '2023-08-14', '2023-08-15', '2023-08-16', '2023-08-17',
#                '2023-08-18', '2023-08-19', '2023-08-20', '2023-08-21',
#                '2023-08-22', '2023-08-23'],
#               dtype='datetime64[ns]', length=600, freq='D')

# %%
df.columns # Colunas
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'Produto'], dtype='object')

# %%
df.to_numpy() # Todos os valores, sem index e colunas
# Out:
# array([[-1.50031701e+00, -1.14753887e+00,  8.76408157e-01, ...,
#          1.00000000e+00,  0.00000000e+00,  1.72167210e+00],
#        [ 7.79476638e-01,  6.65829639e-01,  5.77448005e-01, ...,
#          1.00000000e+00,  1.00000000e+00,  5.18998649e-01],
#        [-7.82323370e-02,  2.22299839e-01,  6.07058137e-02, ...,
#          1.00000000e+00,  2.00000000e+00, -1.73910359e-02],
#        ...,
#        [-8.04089417e-01,  1.45729072e+00,  5.50250504e-01, ...,
#          1.00000000e+00,  5.97000000e+02, -1.17179204e+00],
#        [ 9.43356882e-02, -4.98556016e-01, -7.54836682e-01, ...,
#          1.00000000e+00,  5.98000000e+02, -4.70316248e-02],
#        [ 4.03161525e-01, -1.34335402e+00,  1.24839669e+00, ...,
#          1.00000000e+00,  5.99000000e+02, -5.41588654e-01]])

# %%
df.T # Transposta
# Out:
#          2022-01-01  2022-01-02  2022-01-03  2022-01-04  2022-01-05  \
# A         -1.500317    0.779477   -0.078232    0.865010   -1.413822
# B         -1.147539    0.665830    0.222300   -1.661046    0.463694
# C          0.876408    0.577448    0.060706    0.817054    1.050720
# D         88.000000   88.000000   88.000000   88.000000   88.000000
# E         -0.005721   -0.281789   -0.933266   -1.371363    1.756232
# F          1.000000    1.000000    1.000000    1.000000    1.000000
# G          0.000000    1.000000    2.000000    3.000000    4.000000
# Produto    1.721672    0.518999   -0.017391   -1.436822   -0.655580
#
#          2022-01-06  2022-01-07  2022-01-08  2022-01-09  2022-01-10  \
# A          0.332259    1.861717   -1.011126    0.635914    0.162249
# B          0.182653    0.524315    0.252798    0.204286    0.288972
# C          0.678313   -1.020226   -0.422521    1.150767   -0.581700
# D         88.000000   88.000000   88.000000   88.000000   88.000000
# ...

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                    7                    7                    7
# B  2019-01-01 00:00:00  2019-01-01 00:00:00  2019-01-01 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 test                train                 test
# F               python               python               python
#
#                      3
# A                    7
# B  2019-01-01 00:00:00
# C                  1.0
# D                    3
# E                train
# F               python

# %%
df2.to_numpy()
# Out:
# array([[7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'test', 'python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'train', 'python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'test', 'python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'train', 'python']],
#       dtype=object)
