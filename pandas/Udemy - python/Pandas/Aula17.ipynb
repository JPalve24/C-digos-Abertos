# %%
#VISUALIZANDO DADOS

import pandas as pd
import numpy as np
import matplotlib_inline
import matplotlib.pyplot as plt

# %%
plt.style.available

# %%
plt.rcParams["figure.figsize"] = (20, 7) # escala do gráfico

# %%
d = pd.read_csv("C:/Users/alves/OneDrive/Área de Trabalho/Udemy/titanic_train.csv")

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.plot(d.Age, "*-") # gráfico das idades, linha
plt.show()

# %%
plt.plot(d.Age, "-") # gráfico das idades, linha
plt.show()

# %%
plt.plot(d.Age, "*-r") # gráfico das idades, linha
plt.show()

# %%
plt.plot(d.Age, "*-") # gráfico das idades, linha
plt.title("Informações dos passageiros do titanic")
plt.xlabel("Passageiro")
plt.ylabel("Idade")
plt.show()

# %%
# esticar os dados e aumentar as legendas
plt.plot(d.Age, "*-") # gráfico das idades, linha
plt.title("Informações dos passageiros do titanic")
plt.xlabel("Passageiro", size = 14)
plt.ylabel("Idade")
plt.show()

# %%
plt.plot(d.Age, "*-") # gráfico das idades, linha
plt.title("Informações dos passageiros do titanic", size = 18)
plt.xlabel("Passageiro", size = 18)
plt.ylabel("Idade", size = 18)
plt.show()
# O comprimento do gráfico se muda na função lá de cima

# %%
d.Age.plot()
plt.show()

# %%
d.plot() # não especificou as colunas, plotou todas
# Out:
# <AxesSubplot:>

# %%
# Gráfico de distribuição

plt.scatter(d.PassengerId, d.Age)
plt.show()

# %%
plt.scatter(d.PassengerId, d.Age, color = "red")
plt.show()

# %%
plt.scatter(d.PassengerId, d.Age, color = "pink")
plt.show()

# %%
plt.scatter(d.PassengerId, d.Age, marker = "+")
plt.show()

# %%
plt.scatter(d.PassengerId, d.Age, marker = "<")
plt.show()

# %%
# Histograma

d.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
d.Age.hist()
plt.xlabel("Idade",size = 20)
plt.ylabel("Frequência Observada", size = 20)
# Salvando Figuras

plt.savefig("nome_fig.png", Transparent = False) # Salva a ultima figura, tem que tá na celula da figura, se Transparent = True, a figura não tem fundo

plt.show()
